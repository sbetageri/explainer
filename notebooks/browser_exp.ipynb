# %%
import os
from termios import BSDLY

# %%
from strands import Agent

# %%
from strands.models.anthropic import AnthropicModel

# %%
from browser import BrowserTool

# %%
from markdownify import markdownify as md

# %%
from pydantic import BaseModel, Field

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
model = AnthropicModel(
    client_args = {
        "api_key": os.getenv("ANTHROP_API_KEY"),
    },
    max_tokens=4096,
    model_id="claude-sonnet-4-5"
)

# %%
browser = BrowserTool(dst_dir='../working_dir', headless=False)

# %%
agent = Agent(model=model,
              tools=[
                  browser.navigate,
                  browser.save_as_pdf,
                  browser.save_html,
                  browser.save_current_page_as_pdf,
                  browser.save_html,
                  browser.click,
                  browser.fill_form,
                  browser.get_text,
                  browser.get_current_url],
              system_prompt="""You are a web crawling agent.
              Your aim is to traverse a given website as per instructions that you will receive.
              Along with that, you are to use the tools at your disposal. You will click on any popups in an appropriate manner to remove it as efficiently as possible. You will also click on any cookie requests to ensure that the main content of the page is visible without any obstruction.
              """
              )

# %%
resp = agent("Navigate to https://strandsagents.com/latest/")
# Out:
# I'll navigate to that URL for you.
# Tool #1: navigate
# Successfully navigated to https://strandsagents.com/latest/. The page has loaded with a status code of 200. Is there anything specific you'd like me to do on this page, such as extract information, save it as a PDF, or interact with any elements?

# %%
resp = agent("There is a request for a cookie consent. Can you click on accept?")
# Out:
# I'll look for the cookie consent button and click on accept.
# Tool #2: click
# Let me try a different selector for the accept button:
# Tool #3: click
# Perfect! I've successfully clicked the Accept button for the cookie consent. The cookies have been accepted and the page should now be clear of the consent popup.

# %%
resp = agent("How did you click on the cookie consent? Tell me your methodology.")
# Out:
# Great question! Let me explain my methodology for clicking the cookie consent:
#
# ## My Approach:
#
# ### First Attempt:
# I initially tried a more specific selector:
# ```css
# button[aria-label="Accept cookies"]
# ```
#
# This targeted a button element with an aria-label attribute containing "Accept cookies". This is a common pattern for accessible cookie consent buttons. However, this attempt **failed with a timeout**, meaning the element either didn't exist or wasn't visible/clickable within 30 seconds.
#
# ### Second Attempt (Successful):
# When the first selector failed, I switched to a more flexible approach:
# ```css
# button:has-text("Accept")
# ```
#
# This is a **text-based selector** that looks for any button element containing the text "Accept". This approach is:
# - More flexible (doesn't rely on specific attributes)
# - Language-agnostic to some degree (as long as the button says "Accept")
# - Simpler and catches various implementations of accept buttons
#
# ### Why This Works:
# Cookie consent dialogs vary greatly in their implementation. Some use specific aria-labels, some use classes like "cookie-accept" or "consent-button", and others just have simple buttons with text. By using the text-based selector as a fallback, I was able to match whatever button on the page contained "Accept" as its text content.
#
# This is a common pattern in web automation - start with specific selectors and fall back to more general ones if needed.

# %%
resp = agent("Navigate to any documentation page. Documentation pages can be anything along the lines of user guides, resources, APIs, ")
# Out:
# I'll look for and navigate to a documentation page. Let me first check the current page to find links to documentation, user guides, resources, or API pages.
# Tool #14: click
# Perfect! I've successfully navigated to a documentation page at https://strandsagents.com/latest/documentation/docs/. This appears to be the main documentation section of the Strands Agents website.
# Tool #15: get_current_url
# Great! I'm now on the documentation page titled "Welcome - Strands Agents" at https://strandsagents.com/latest/documentation/docs/. This is the documentation section of the website. Would you like me to explore specific sections, save this page, or navigate to any particular documentation topic?

# %%
class MarkDownModel(BaseModel):
    url: str = Field(description="URL which is being converted to markdown")
    markdown: str = Field(description="Markdown content of the url")

# %%
resp = agent("Extract the main documentation in the given webpage to markdown. Preserve all links and headings", structured_output_model=MarkDownModel)
# Out:
# I'll extract the main documentation content from the webpage and convert it to markdown, preserving all links and headings.
# Tool #4: get_text
# The text extraction is quite messy due to the page structure. Let me try to get the HTML source and then extract the content more cleanly to convert it to markdown.
# Tool #5: save_html
# Let me try extracting the main article content more specifically:
# Tool #6: get_text
# Let me try a different approach and look for the actual documentation content:
# Tool #7: get_text
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Startups/explainer/.venv/lib/python3.12/site-packages/strands/_async.py:33, in run_async(async_func)
#      32 future = executor.submit(context.run, execute)
# ---> 33 return future.result()
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     354 if timeout is None:
# --> 355     waiter.acquire()
#     356     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 resp = agent("Extract the main documentation in the given webpage to markdown. Preserve all links and headings", structured_output_model=MarkDownModel)
#
# File ~/Startups/explainer/.venv/lib/python3.12/site-packages/strands/agent/agent.py:457, in Agent.__call__(self, prompt, invocation_state, structured_output_model, **kwargs)
#     422 def __call__(
#     423     self,
#     424     prompt: AgentInput = None,
#    (...)    428     **kwargs: Any,
#     429 ) -> AgentResult:
#     430     """Process a natural language prompt through the agent's event loop.
#     431
#     432     This method implements the conversational interface with multiple input patterns:
#    (...)    455             - structured_output: Parsed structured output when structured_output_model was specified
#     456     """
# --> 457     return run_async(
#     458         lambda: self.invoke_async(
#     459             prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     460         )
#     461     )
#
# File ~/Startups/explainer/.venv/lib/python3.12/site-packages/strands/_async.py:30, in run_async(async_func)
#      27 def execute() -> T:
#      28     return asyncio.run(execute_async())
# ---> 30 with ThreadPoolExecutor() as executor:
#      31     context = contextvars.copy_context()
#      32     future = executor.submit(context.run, execute)
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/concurrent/futures/thread.py:239, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 if wait:
#     238     for t in self._threads:
# --> 239         t.join()
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:

# %%
markdown_data = md(data)

# %%
markdown_data
# Out:
# 'Welcome - Strands Agents\n\n\n\n\n\n\n[Skip to content](https://strandsagents.com/latest/documentation/docs/#strands-agents-sdk)\n\n\n\n\n\nType to start searching\n\n[sdk-python\n\n* 4,731\n* 570\n* v1.20.0](https://github.com/strands-agents/sdk-python "Go to repository")\n[sdk-typescript\n\n* 344\n* 34\n* v0.1.3](https://github.com/strands-agents/sdk-typescript "Go to repository")\n\n\n\n\n\n* [Home](https://strandsagents.com/latest/)\n\n* [User Guide](https://strandsagents.com/latest/documentation/docs/)\n\n\n* [Examples](https://strandsagents.com/latest/documentation/docs/examples/)\n\n\n* [Community](https://strandsagents.com/latest/documentation/docs/community/community-packages/)\n\n* [Contribute ❤️](https://github.com/strands-agents/sdk-python/blob/main/CONTRIBUTING.md)\n\n* [Python API](https://strandsagents.com/latest/documentation/docs/api-reference/agent/)\n\n* [TypeScript API](https://strandsagents.com/latest/documentation/docs/api-reference/typescript/)\n\n[sdk-python\n\n* 4,731\n* 570\n* v1.20.0](https://github.com/strands-agents/sdk-python "Go to repository")\n[sdk-typescript\n\n* 344\n* 34\n* v0.1.3](https://github.com/strands-agents/sdk-typescript "Go to repository")\n\n* [Home](https://strandsagents.com/latest/)\n\n\n\n\n\n\n\n\n\n* [User Guide](https://strandsagents.com/latest/documentation/docs/)\n\n\n\n\n  User Guide\n\n  + Quickstart\n\n\n\n\n\n\n    Quickstart\n\n    - [Getting Started](https://strandsagents.com/latest/documentation/docs/user-guide/quickstart/overview/)\n\n    - [Python](https://strandsagents.com/latest/documentation/docs/user-guide/quickstart/python/)\n\n    - [TypeScript](https://strandsagents.com/latest/documentation/docs/user-guide/quickstart/typescript/)\n\n\n\n\n\n\n\n\n\n\n  + Concepts\n\n\n\n\n\n\n    Concepts\n\n    - Agents\n\n\n\n\n\n\n      Agents\n\n      * [Agent Loop](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/agents/agent-loop/)\n\n      * [State](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/agents/state/)\n\n      * [Session Management](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/agents/session-management/)\n\n      * [Prompts](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/agents/prompts/)\n\n      * [Hooks](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/agents/hooks/)\n\n      * [Structured Output](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/agents/structured-output/)\n\n      * [Conversation Management](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/agents/conversation-management/)\n\n\n\n\n\n\n\n\n\n\n    - [Tools](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/)\n\n\n\n\n      Tools\n\n      * [Creating Custom Tools](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/custom-tools/)\n\n      * [Model Context Protocol (MCP)](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/mcp-tools/)\n\n      * [Executors](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/executors/)\n\n      * [Community Tools Package](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/community-tools-package/)\n\n\n\n\n\n\n\n\n\n\n    - [Model Providers](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/model-providers/)\n\n\n\n\n      Model Providers\n\n      * [Amazon Bedrock](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/model-providers/amazon-bedrock/)\n\n      * [Amazon Nova](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/model-providers/amazon-nova/)\n\n      * [Anthropic](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/model-providers/anthropic/)\n\n      * [Gemini](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/model-providers/gemini/)\n\n      * ...

# %%
with open('test.md', 'w') as f:
    f.write(markdown_data)

# %%
resp = agent("Save the PDF and the HTML")
# Out:
# I'll save both the PDF and HTML of the current documentation page.
# Tool #16: save_current_page_as_pdf
#
# Tool #17: save_html
# Exception in callback _UnixReadPipeTransport._read_ready()
# handle: <Handle _UnixReadPipeTransport._read_ready()>
# Traceback (most recent call last):
#   File "/Users/sri/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x107c00dc0> is already entered
# Exception in callback _UnixReadPipeTransport._read_ready()
# handle: <Handle _UnixReadPipeTransport._read_ready()>
# Traceback (most recent call last):
#   File "/Users/sri/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x107c00dc0> is already entered
# Exception in callback _UnixReadPipeTransport._read_ready()
# handle: <Handle _UnixReadPipeTransport._read_ready()>
# Traceback (most recent call last):
#   File "/Users/sri/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x1104c2340> is already entered
# Perfect! I've successfully saved both files:
#
# 1. **PDF**: `../working_dir/strandsagents.com/2025-12-25/pdf/strandsagents.com-latest-documentation-docs.pdf`
# 2. **HTML**: `../working_dir/strandsagents.com/2025-12-25/source/strandsagents.com-latest-documentation-docs.html`
#
# Both the PDF and HTML versions of the documentation page have been saved. Is there anything else you'd like me to do on this site?

# %%
re

# %%
browser.navigate("https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/custom-tools/#example-with-multiple-tools-in-a-class")
# Out:
# {'status': 'success',
#  'message': 'Successfully navigated to https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/custom-tools/#example-with-multiple-tools-in-a-class',
#  'final_url': 'https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/custom-tools/#example-with-multiple-tools-in-a-class',
#  'status_code': 200}

# %%
browser.save_current_page_as_pdf('screenshots/example.pdf')
# Out:
# {'status': 'success',
#  'message': 'Successfully saved current page as PDF',
#  'current_url': 'https://strandsagents.com/latest/documentation/docs/user-guide/concepts/tools/custom-tools/#example-with-multiple-tools-in-a-class',
#  'output_path': 'screenshots/example.pdf'}
